# %%
import pandas as pd
import folium
import os
import datetime

# %% [markdown]
# ## The path to our geodata.

# %%
beats = os.path.join('..', 'data', 'SPD_Beats_WGS84.json')

# %% [markdown]
# ## Importing crime data

# %%
crime_data = os.path.join('..', 'data', 'Crime_Data.csv')
crime_df = pd.read_csv(crime_data)
crime_df['Occurred Date'] = pd.to_datetime(crime_df['Occurred Date'])
crime_df = crime_df[crime_df['Occurred Date'] > pd.Timestamp(2017,1,1)]
crime_df['Count'] = 1

# %% [markdown]
# ## Making a total crime incidents layer

# %%
total_crime_df = crime_df[['Occurred Date', 'Beat', 'Count']]

# %%
total_crime_per_beat = total_crime_df.groupby('Beat', as_index=False).sum()

# %%
m = folium.Map(location=[47.6553, -122.3035], zoom_start=12, min_zoom=10)

total_crime_layer = folium.Choropleth(
    geo_data=beats,
    data=total_crime_per_beat,
    columns=['Beat', 'Count'],
    key_on= 'feature.properties.beat',
    fill_color='YlOrRd',
    nan_fill_color = 'none',
    line_weight = 0.5,
    name='Total Crime Incidents',
    legend_name = 'Total Crime Incidents 2018'
)

total_crime_layer.add_to(m)

# %% [markdown]
# # Making crime layers for specific crimes which may be of interest to graduate students

# %%
crime_df.head()
# Out:
#    Report Number Occurred Date  Occurred Time Reported Date  Reported Time  \
# 0   2.018000e+13    2018-10-24         2259.0    10/24/2018         2337.0
# 1   2.018000e+13    2018-10-24         2210.0    10/24/2018         2210.0
# 2   2.018000e+13    2018-10-24         2042.0    10/24/2018         2236.0
# 3   2.018000e+13    2018-10-24         1657.0    10/24/2018         1657.0
# 4   2.018000e+13    2018-10-24         1655.0    10/24/2018         1700.0
#
#     Crime Subcategory Primary Offense Description   Precinct Sector Beat  \
# 0      THEFT-SHOPLIFT              THEFT-SHOPLIFT  SOUTHWEST      F   F3
# 1  AGGRAVATED ASSAULT         ASSLT-AGG-BODYFORCE  SOUTHWEST      W   W1
# 2            TRESPASS                    TRESPASS      NORTH      J   J1
# 3           CAR PROWL              THEFT-CARPROWL       WEST      K   K1
# 4      THEFT-SHOPLIFT              THEFT-SHOPLIFT       EAST      C   C1
#
#                Neighborhood  Count
# 0                SOUTH PARK      1
# 1  COMMERCIAL HARBOR ISLAND      1
# 2                 GREENWOOD      1
# 3       DOWNTOWN COMMERCIAL      1
# 4  CENTRAL AREA/SQUIRE PARK      1

# %%
theft_category_groupby = crime_df.groupby(['Beat', 'Crime Subcategory'], as_index=False).sum()

# %%
theft_category_groupby = theft_category_groupby[['Beat', 'Crime Subcategory', 'Count']]
# Out:
#      Beat                    Crime Subcategory  Count
# 0      B1                   AGGRAVATED ASSAULT     87
# 1      B1                AGGRAVATED ASSAULT-DV     17
# 2      B1                                ARSON      5
# 3      B1                  BURGLARY-COMMERCIAL    166
# 4      B1   BURGLARY-COMMERCIAL-SECURE PARKING      8
# 5      B1                 BURGLARY-RESIDENTIAL    170
# 6      B1  BURGLARY-RESIDENTIAL-SECURE PARKING    159
# 7      B1                            CAR PROWL    532
# 8      B1                   DISORDERLY CONDUCT      2
# 9      B1                                  DUI     40
# 10     B1            FAMILY OFFENSE-NONVIOLENT     14
# 11     B1                             HOMICIDE      2
# 12     B1                 LIQUOR LAW VIOLATION      4
# 13     B1                  MOTOR VEHICLE THEFT    180
# 14     B1                             NARCOTIC     20
# 15     B1                                 RAPE      8
# 16     B1                   ROBBERY-COMMERCIAL     40
# 17     B1                  ROBBERY-RESIDENTIAL      3
# 18     B1                       ROBBERY-STREET     16
# 19     B1                    SEX OFFENSE-OTHER     17
# 20     B1                      THEFT-ALL OTHER    250
# 21     B1                        THEFT-BICYCLE     87
# 22     B1                       THEFT-BUILDING    120
# 23     B1                       THEFT-SHOPLIFT    167
# 24     B1                             TRESPASS    146
# 25     B1                               WEAPON     13
# 26     B2                   AGGRAVATED ASSAULT     37
# 27     B2                AGGRAVATED ASSAULT-DV     24
# 28     B2                                ARSON      8
# 29     B2                  BURGLARY-COMMERCIAL    146
# ...   ...                                  ...    ...
# 1277   W2                       THEFT-BUILDING     96
# 1278   W2                       THEFT-SHOPLIFT    195
# 1279   W2                             TRESPASS     74
# 1280   W2                               WEAPON      5
# 1281   W3                   AGGRAVATED ASSAULT     22
# 1282   W3                AGGRAVATED ASSAULT-DV     29
# 1283   W3                                ARSON      5
# 1284   W3                  BURGLARY-COMMERCIAL     40
# 1285   W3   BURGLARY-COMMERCIAL-SECURE PARKING      1
# 1286   W3                 BURGLARY-RESIDENTIAL    153
# 1287   W3  BURGLARY-RESIDENTIAL-SECURE PARKING      9
# 1288   W3                            CAR PROWL    522
# 1289   W3                                  DUI     35
# 1290   W3            FAMILY OFFENSE-NONVIOLENT     25
# 1291   W3                             HOMICIDE      1
# 1292   W3                 LIQUOR LAW VIOLATION      1
# 1293   W3                  MOTOR VEHICLE THEFT    169
# 1294   W3                             NARCOTIC     10
# 1295   W3                          PORNOGRAPHY      1
# 1296   W3                                 RAPE      4
# 1297   W3                   ROBBERY-COMMERCIAL      4
# 1298   W3                  ROBBERY-RESIDENTIAL      2
# 1299   W3                       ROBBERY-STREET      9
# 1300   W3                    SEX OFFENSE-OTHER     15
# 1301   W3                      THEFT-ALL OTHER    163
# 1302   W3                        THEFT-BICYCLE     18
# 1303   W3                       THEFT-BUILDING     28
# 1304   W3                       THEFT-SHOPLIFT     40
# 1305   W3                             TRESPASS     29
# 1306   W3                               WEAPON      2
#
# [1307 rows x 3 columns]

# %%
bike_theft_groupby = theft_category_groupby[theft_category_groupby['Crime Subcategory'] == 'THEFT-BICYCLE']

# %%
bike_theft_layer = folium.Choropleth(
    geo_data=beats,
    data=bike_theft_groupby,
    columns=['Beat', 'Count'],
    key_on= 'feature.properties.beat',
    fill_color='YlOrRd',
    nan_fill_color = 'none',
    line_weight = 0.5,
    name='Bike Theft',
    legend_name = 'Incidents of Bike Theft, Since 2017'
)

bike_theft_layer.add_to(m)

# %%
car_prowl = theft_category_groupby[theft_category_groupby['Crime Subcategory'] == 'CAR PROWL']

# %%
car_prowl_layer = folium.Choropleth(
    geo_data=beats,
    data=car_prowl,
    columns=['Beat', 'Count'],
    key_on= 'feature.properties.beat',
    fill_color='YlOrRd',
    nan_fill_color = 'none',
    line_weight = 0.5,
    name='Car Prowl',
    legend_name = 'Incidents of Car Prowl, Since 2017'
)

car_prowl_layer.add_to(m)

# %%
folium.LayerControl().add_to(m)
m.save('beats.html')
